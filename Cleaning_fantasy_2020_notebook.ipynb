# %%
# Dependencies
import pandas as pd

# %%
# load file
working_file = pd.read_csv('fantasy_2020_results.csv', encoding='UTF-8')
working_file
# Out:
#                      ï»¿PLAYER   GP  ATT  CMP   YDS  YDS/G   TD  INT   RATE  \
# 0      Aaron RodgersÂ QBÂ Â GB   16  526  372  4299  268.7   48    5  121.5
# 1        Josh AllenÂ QBÂ Â BUF   16  572  396  4544    284   37   10  107.2
# 2    Patrick MahomesÂ QBÂ Â KC   15  588  390  4740    316   38    6  108.2
# 3    Russell WilsonÂ QBÂ Â SEA   16  558  384  4212  263.3   40   13  105.1
# 4    Deshaun WatsonÂ QBÂ Â HOU   16  544  382  4823  301.4   33    7  112.4
# ..                         ...  ...  ...  ...   ...    ...  ...  ...    ...
# 95     Reid SinnettÂ QBÂ Â MIA  â€”  â€”  â€”   â€”    â€”  â€”  â€”    â€”
# 96  Clayton ThorsonÂ QBÂ Â NYG  â€”  â€”  â€”   â€”    â€”  â€”  â€”    â€”
# 97      Josh McCownÂ QBÂ Â HOU  â€”  â€”  â€”   â€”    â€”  â€”  â€”    â€”
# 98     Sean MannionÂ QBÂ Â SEA  â€”  â€”  â€”   â€”    â€”  â€”  â€”    â€”
# 99        Matt MooreÂ QBÂ Â KC  â€”  â€”  â€”   â€”    â€”  â€”  â€”    â€”
#
#    ATT.1 YDS.1  AVG TD.1   FL   FPTS  FPPG
# ...

# %%
# let us change the values __ to zeros to make calculations possible
working_file = working_file.replace('—',0)
working_file
# Out:
#                      ï»¿PLAYER   GP  ATT  CMP   YDS  YDS/G   TD  INT   RATE  \
# 0      Aaron RodgersÂ QBÂ Â GB   16  526  372  4299  268.7   48    5  121.5
# 1        Josh AllenÂ QBÂ Â BUF   16  572  396  4544    284   37   10  107.2
# 2    Patrick MahomesÂ QBÂ Â KC   15  588  390  4740    316   38    6  108.2
# 3    Russell WilsonÂ QBÂ Â SEA   16  558  384  4212  263.3   40   13  105.1
# 4    Deshaun WatsonÂ QBÂ Â HOU   16  544  382  4823  301.4   33    7  112.4
# ..                         ...  ...  ...  ...   ...    ...  ...  ...    ...
# 95     Reid SinnettÂ QBÂ Â MIA  â€”  â€”  â€”   â€”    â€”  â€”  â€”    â€”
# 96  Clayton ThorsonÂ QBÂ Â NYG  â€”  â€”  â€”   â€”    â€”  â€”  â€”    â€”
# 97      Josh McCownÂ QBÂ Â HOU  â€”  â€”  â€”   â€”    â€”  â€”  â€”    â€”
# 98     Sean MannionÂ QBÂ Â SEA  â€”  â€”  â€”   â€”    â€”  â€”  â€”    â€”
# 99        Matt MooreÂ QBÂ Â KC  â€”  â€”  â€”   â€”    â€”  â€”  â€”    â€”
#
#    ATT.1 YDS.1  AVG TD.1   FL   FPTS  FPPG
# ...

# %%
# export the data frame into a csv
working_file.to_csv("Fantasy_2020_results_clean.csv", encoding = "UTF-8")

# %%
# load file
working_file_2 = pd.read_csv('fantasy_2019_results.csv', encoding='UTF-8')
working_file_2

# %%
# let us merge the dataframes by index
Final_data = pd.merge(working_file,working_file_2 , left_index=True, right_index=True)
